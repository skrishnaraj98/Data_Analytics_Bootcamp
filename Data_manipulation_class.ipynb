# %%
## Data manipulation and Analysis are crucial tasks in Data Science.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 pwd
#
# NameError: name 'pwd' is not defined

# %%
pwd
# Out:
# 'c:\\Users\\lenovo\\Python_udemy\\1.Python_class'

# %%
cd
# Out:
# C:\Users\lenovo

# %%
df = pd.read_csv("Downloads\\Sales.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.describe()       ## It only takes numerical column and omits categorical column
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
df.dtypes
# Out:
# Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object

# %%
## Handling Missing Value

df.isnull() ##False means is not null.
# Out:
#      Transaction ID   Date  Product Category  Product Name  Units Sold  \
# 0             False  False             False         False       False
# 1             False  False             False         False       False
# 2             False  False             False         False       False
# 3             False  False             False         False       False
# 4             False  False             False         False       False
# ..              ...    ...               ...           ...         ...
# 235           False  False             False         False       False
# 236           False  False             False         False       False
# 237           False  False             False         False       False
# 238           False  False             False         False       False
# 239           False  False             False         False       False
#
#      Unit Price  Total Revenue  Region  Payment Method
# 0         False          False   False           False
# ...

# %%
df.isnull().any()  ## .all() and .any() are used to check for Boolean conditions in df or series. 

## .all() return True if all the elements along a given axis are True. 
## .any() returns True if at least one of the elements along a given axis is True.
# Out:
# Transaction ID      False
# Date                False
# Product Category    False
# Product Name        False
# Units Sold          False
# Unit Price          False
# Total Revenue       False
# Region              False
# Payment Method      False
# dtype: bool

# %%
# Our sales dataset doesnt have a missing data from the above result.

# %%
df["Disount"] = df["Unit Price"] == df["Total Revenue"]

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Disount
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# Disount             0
# dtype: int64

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Disount
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True

# %%
df["Disount"] = 0

# %%
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  02-01-2024  Home Appliances
# 2             10003  03-01-2024         Clothing
# 3             10004  04-01-2024            Books
# 4             10005  05-01-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df.fillna(0)    ## This fill in empty cells.
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  02-01-2024  Home Appliances
# 2             10003  03-01-2024         Clothing
# 3             10004  04-01-2024            Books
# 4             10005  05-01-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df["Disount"] = df["Disount"].fillna(df["Unit Price"].mean())

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Disount
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.drop("Disount", axis =1, inplace= True)

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df["Discount"] = df["Unit Price"] > 100.00

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Discount
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False

# %%
df[df["Discount"] == True] = 100
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14180\1487994825.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '100' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df[df["Discount"] == True] = 100

# %%
df["Discount"] = 0

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0             100         100              100                      100
# 1             100         100              100                      100
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0         100      100.00         100.00            100            100
# 1         100      100.00         100.00            100            100
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Discount
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df["Dis"] = df["Unit Price"]>=100

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0             100         100              100                      100
# 1             100         100              100                      100
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0         100      100.00         100.00            100            100
# 1         100      100.00         100.00            100            100
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Discount    Dis
# 0         0   True
# 1         0   True
# 2         0  False
# 3         0  False
# ...

# %%
df[df["Dis"]==False] = 500
df[df["Dis"]==True] = 1000

# %%
df.head()
# Out:
#    Transaction ID  Date Product Category Product Name  Units Sold  Unit Price  \
# 0            1000  1000             1000         1000        1000      1000.0
# 1            1000  1000             1000         1000        1000      1000.0
# 2             500   500              500          500         500       500.0
# 3             500   500              500          500         500       500.0
# 4             500   500              500          500         500       500.0
#
#    Total Revenue Region Payment Method  Discount   Dis
# 0         1000.0   1000           1000      1000  1000
# 1         1000.0   1000           1000      1000  1000
# 2          500.0    500            500       500   500
# 3          500.0    500            500       500   500
# 4          500.0    500            500       500   500

# %%
df = pd.read_csv("Downloads\\Sales.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
import numpy as np
df["Discount"] = np.nan

df.loc[df["Total Revenue"]==df["Unit Price"], "Discount"] = 0
df.loc[df["Total Revenue"] != df["Unit Price"], "Discount"] = 100

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Discount
# 0     100.0
# 1       0.0
# 2     100.0
# 3     100.0
# 4       0.0

# %%
df.replace(0, np.nan)
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  02-01-2024  Home Appliances
# 2             10003  03-01-2024         Clothing
# 3             10004  04-01-2024            Books
# 4             10005  05-01-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df.isnull().all()
# Out:
# Transaction ID      False
# Date                False
# Product Category    False
# Product Name        False
# Units Sold          False
# Unit Price          False
# Total Revenue       False
# Region              False
# Payment Method      False
# Discount            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# Discount            0
# dtype: int64

# %%
df.isnull()
# Out:
#      Transaction ID   Date  Product Category  Product Name  Units Sold  \
# 0             False  False             False         False       False
# 1             False  False             False         False       False
# 2             False  False             False         False       False
# 3             False  False             False         False       False
# 4             False  False             False         False       False
# ..              ...    ...               ...           ...         ...
# 235           False  False             False         False       False
# 236           False  False             False         False       False
# 237           False  False             False         False       False
# 238           False  False             False         False       False
# 239           False  False             False         False       False
#
#      Unit Price  Total Revenue  Region  Payment Method  Discount
# ...

# %%
df["Discount"] = df["Discount"].replace(0, np.nan)

# %%
df.isnull().any()
# Out:
# Transaction ID      False
# Date                False
# Product Category    False
# Product Name        False
# Units Sold          False
# Unit Price          False
# Total Revenue       False
# Region              False
# Payment Method      False
# Discount             True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Transaction ID       0
# Date                 0
# Product Category     0
# Product Name         0
# Units Sold           0
# Unit Price           0
# Total Revenue        0
# Region               0
# Payment Method       0
# Discount            97
# dtype: int64

# %%
df["Discount"].fillna(1)
# Out:
# 0      100.0
# 1        1.0
# 2      100.0
# 3      100.0
# 4        1.0
#        ...
# 235      1.0
# 236    100.0
# 237    100.0
# 238      1.0
# 239    100.0
# Name: Discount, Length: 240, dtype: float64

# %%
df["Discount"]
# Out:
# 0      100.0
# 1        NaN
# 2      100.0
# 3      100.0
# 4        NaN
#        ...
# 235      NaN
# 236    100.0
# 237    100.0
# 238      NaN
# 239    100.0
# Name: Discount, Length: 240, dtype: float64

# %%
df_filled = df.fillna(0)

# %%
df_filled
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  02-01-2024  Home Appliances
# 2             10003  03-01-2024         Clothing
# 3             10004  04-01-2024            Books
# 4             10005  05-01-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df_filled.isnull().any()
# Out:
# Transaction ID      False
# Date                False
# Product Category    False
# Product Name        False
# Units Sold          False
# Unit Price          False
# Total Revenue       False
# Region              False
# Payment Method      False
# Discount            False
# dtype: bool

# %%
## Filling missing values with the mean of a column. 

df["Discount_filled"] = df["Discount"].fillna(df["Unit Price"].mean())

# %%
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  01-01-2024      Electronics
# 1             10002  02-01-2024  Home Appliances
# 2             10003  03-01-2024         Clothing
# 3             10004  04-01-2024            Books
# 4             10005  05-01-2024  Beauty Products
# ..              ...         ...              ...
# 235           10236  23-08-2024  Home Appliances
# 236           10237  24-08-2024         Clothing
# 237           10238  25-08-2024            Books
# 238           10239  26-08-2024  Beauty Products
# 239           10240  27-08-2024           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
## Renaming columns

# %%
df.dtypes
# Out:
# Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# Discount            float64
# Discount_filled     float64
# dtype: object

# %%
df1 = df.rename(columns = {"Unit Price": "UPrice"})

# %%
df1.head(2)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  01-01-2024      Electronics     iPhone 14 Pro           2
# 1           10002  02-01-2024  Home Appliances  Dyson V11 Vacuum           1
#
#    UPrice  Total Revenue         Region Payment Method  Discount  \
# 0  999.99        1999.98  North America    Credit Card     100.0
# 1  499.99         499.99         Europe         PayPal       NaN
#
#    Discount_filled
# 0       100.000000
# 1       236.395583

# %%
## Change Data types

# %%
df.dtypes
# Out:
# Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# Discount            float64
# Discount_filled     float64
# dtype: object

# %%
df["UPrice_New"] = df["Unit Price"].astype(int)
df.head(2)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  01-01-2024      Electronics     iPhone 14 Pro           2
# 1           10002  02-01-2024  Home Appliances  Dyson V11 Vacuum           1
#
#    Unit Price  Total Revenue         Region Payment Method  Discount  \
# 0      999.99        1999.98  North America    Credit Card     100.0
# 1      499.99         499.99         Europe         PayPal       NaN
#
#    Discount_filled  UPrice_New
# 0       100.000000         999
# 1       236.395583         499

# %%
df.drop("Discount_filled", axis = 1, inplace= True)

# %%
df.drop("UPrice_New", axis =1, inplace = True)

# %%
df.head(2)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  01-01-2024      Electronics     iPhone 14 Pro           2
# 1           10002  02-01-2024  Home Appliances  Dyson V11 Vacuum           1
#
#    Unit Price  Total Revenue         Region Payment Method  Discount
# 0      999.99        1999.98  North America    Credit Card     100.0
# 1      499.99         499.99         Europe         PayPal       NaN

# %%
# Applying a function to any one column in the df : 

df["New_Inventory"] = df["Units Sold"].apply(lambda x: x**2 )

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Discount  New_Inventory
# 0     100.0              4
# 1       NaN              1
# ...

# %%
## Data Aggregating and Grouping

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Discount  New_Inventory
# 0     100.0              4
# 1       NaN              1
# ...

# %%
grouped_mean = df.groupby("Product Category")["Total Revenue"].mean()

# %%
print(grouped_mean)
# Out:
# Product Category
# Beauty Products     65.54750
# Books               46.54825
# Clothing           203.22325
# Electronics        874.56025
# Home Appliances    466.15400
# Sports             358.16300
# Name: Total Revenue, dtype: float64

# %%
grouped_sum = df.groupby(["Product Category","Region"])["Total Revenue"].sum()
print(grouped_sum)
# Out:
# Product Category  Region
# Beauty Products   Europe            2621.90
# Books             North America     1861.93
# Clothing          Asia              8128.93
# Electronics       North America    34982.41
# Home Appliances   Europe           18646.16
# Sports            Asia             14326.52
# Name: Total Revenue, dtype: float64

# %%
df.loc[df["Product Category"] == "Book", "Europe"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lenovo\Python_udemy\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Europe'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 df.loc[df["Product Category"] == "Book", "Europe"]
# ...

# %%
df[df["Product Category"] == "Beauty Products"]["Region"].value_counts()
# Out:
# Region
# Europe    40
# Name: count, dtype: int64

# %%
grouped_agg = df.groupby("Region")["Total Revenue"].agg(["mean", "sum", "count"])
grouped_agg
# Out:
#                      mean       sum  count
# Region
# Asia           280.693125  22455.45     80
# Europe         265.850750  21268.06     80
# North America  460.554250  36844.34     80

# %%
## Mergining and Joining DataFrames

# %%
df1 = pd.DataFrame({"Key": ["A","B","C"], "Value1":[1,2,3]})
df2 = pd.DataFrame({"Key": ["A","B","D"], "Value1":[4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value1
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merge Dataframe on the "Key" column:

pd.merge(df1,df2, on="Key", how = "inner")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1         4
# 1   B         2         5

# %%
pd.merge(df1,df2, on="Key", how = "outer")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0       4.0
# 1   B       2.0       5.0
# 2   C       3.0       NaN
# 3   D       NaN       6.0

# %%
pd.merge(df1,df2, on="Key", how = "left")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1       4.0
# 1   B         2       5.0
# 2   C         3       NaN

# %%
pd.merge(df1,df2, on="Key", how = "right")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0         4
# 1   B       2.0         5
# 2   D       NaN         6
