# %%
## Seaborn is a popular visualization library based on Matplotlib.

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
# Basic Plotting with Seaborn: 
tips_data = sns.load_dataset("tips")            ## .load_dataset is a method which contains online dataset,
                                                # so you just have to select and get started with. 
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x="total_bill", y="tip", data = tips_data)
plt.title("Scatter Plot of total bill vs tips")
plt.show()

# %%
## Line plot

sns.lineplot(x="size", y="total_bill", data = tips_data)
plt.title("Line plot of total bill by size")
# Out:
# Text(0.5, 1.0, 'Line plot of total bill by size')

# %%
## Categorical plots: 

## BAr plot: 

sns.barplot(x="day", y="total_bill", data = tips_data)
plt.title("Bar plot of total bill by day")
plt.show()

# %%
## Box plot: 

sns.boxplot(x="day", y = "total_bill", data = tips_data)
plt.show()

# %%
## Violin plot: 

sns.violinplot(x="day", y="total_bill", data = tips_data, color= "pink")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Histogram: 

sns.histplot(tips_data["total_bill"], bins= 10, kde= True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE - Kernel Density Estimator: 

sns.kdeplot(tips_data["total_bill"], fill= True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pairplot: 

sns.pairplot(tips_data)

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Heatmap: 

corr = tips_data[["total_bill", "tip","size"]].corr()

corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap= "coolwarm")
# Out:
# <Axes: >

# %%
import pandas as  pd
sales_df = pd.read_csv("Downloads//Sales.csv")
sales_df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  01-01-2024      Electronics            iPhone 14 Pro
# 1           10002  02-01-2024  Home Appliances         Dyson V11 Vacuum
# 2           10003  03-01-2024         Clothing         Levi's 501 Jeans
# 3           10004  04-01-2024            Books        The Da Vinci Code
# 4           10005  05-01-2024  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
#Plot total sales by products: 

plt.figure(figsize=(10,6))

sns.barplot(x="Product Category", y = "Total Revenue", data = sales_df, estimator=sum)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Revenue'>
